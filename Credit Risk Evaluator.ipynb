# %%
import numpy as np
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

# %%
train_df = pd.read_csv(Path('Resources/2019loans.csv'))
test_df = pd.read_csv(Path('Resources/2020Q1loans.csv'))

# %%
train_df
# Out:
#        Unnamed: 0   index  loan_amnt  int_rate  installment home_ownership  \
# 0           57107   57107    13375.0    0.1797       483.34       MORTGAGE
# 1          141451  141451    21000.0    0.1308       478.68       MORTGAGE
# 2          321143  321143    20000.0    0.1240       448.95       MORTGAGE
# 3           11778   11778     3000.0    0.1240       100.22           RENT
# 4          169382  169382    30000.0    0.1612      1056.49       MORTGAGE
# ...           ...     ...        ...       ...          ...            ...
# 12175      354912  354912    19975.0    0.2565       801.09           RENT
# 12176      354944  354944    15000.0    0.1774       540.34           RENT
# 12177      354973  354973     3600.0    0.1862       131.28           RENT
# 12178      355002  355002    15000.0    0.0881       475.68       MORTGAGE
# 12179      355307  355307    15000.0    0.1774       540.34           RENT
#
#        annual_inc verification_status loan_status pymnt_plan  ...  \
# ...

# %%
# Convert categorical data to numeric and separate target feature for training data
train_df = pd.get_dummies(train_df)
train_col = train_df.columns

# %%
# Convert categorical data to numeric and separate target feature for testing data
test_df = pd.get_dummies(test_df)
test_col = test_df.columns

# %%
# add missing dummy variables to testing set
missing_variables = []
for col in train_col:
    if col not in test_col:
        missing_variables.append(col)

print(missing_variables)
# Out:
# ['debt_settlement_flag_Y']

# %%
test_df.astype('int')
train_df.astype('int')
# Out:
#        Unnamed: 0   index  loan_amnt  int_rate  installment  annual_inc  dti  \
# 0           57107   57107      13375         0          483      223000   29
# 1          141451  141451      21000         0          478      123000   11
# 2          321143  321143      20000         0          448      197000   11
# 3           11778   11778       3000         0          100       45000   18
# 4          169382  169382      30000         0         1056      133000   27
# ...           ...     ...        ...       ...          ...         ...  ...
# 12175      354912  354912      19975         0          801       28000   28
# 12176      354944  354944      15000         0          540       50000   23
# 12177      354973  354973       3600         0          131       60000   28
# 12178      355002  355002      15000         0          475       62000   11
# 12179      355307  355307      15000         0          540       54080   21
#
# ...

# %%
test_df.columns
# Out:
# Index(['Unnamed: 0', 'index', 'loan_amnt', 'int_rate', 'installment',
#        'annual_inc', 'dti', 'delinq_2yrs', 'inq_last_6mths', 'open_acc',
#        'pub_rec', 'revol_bal', 'total_acc', 'out_prncp', 'out_prncp_inv',
#        'total_pymnt', 'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int',
#        'total_rec_late_fee', 'recoveries', 'collection_recovery_fee',
#        'last_pymnt_amnt', 'collections_12_mths_ex_med', 'policy_code',
#        'acc_now_delinq', 'tot_coll_amt', 'tot_cur_bal', 'open_acc_6m',
#        'open_act_il', 'open_il_12m', 'open_il_24m', 'mths_since_rcnt_il',
#        'total_bal_il', 'il_util', 'open_rv_12m', 'open_rv_24m', 'max_bal_bc',
#        'all_util', 'total_rev_hi_lim', 'inq_fi', 'total_cu_tl', 'inq_last_12m',
#        'acc_open_past_24mths', 'avg_cur_bal', 'bc_open_to_buy', 'bc_util',
#        'chargeoff_within_12_mths', 'delinq_amnt', 'mo_sin_old_il_acct',
#        'mo_sin_old_rev_tl_op', 'mo_sin_rcnt_rev_tl_op', 'mo_sin_rcnt_tl',
# ...

# %%
test_df['debt_settlement_flag_Y'] = abs(test_df['debt_settlement_flag_N']-1)

# %%
# Train the Logistic Regression model on the unscaled data and print the model score
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(max_iter=10000000)
classifier
# Out:
# LogisticRegression(max_iter=10000000)

# %%
X_train= train_df.drop(['loan_status_low_risk'], axis=1).drop(['loan_status_high_risk'], axis=1)
y_train= train_df['loan_status_low_risk']
X_test= test_df.drop(['loan_status_low_risk'], axis=1).drop(['loan_status_high_risk'], axis=1)
y_test= test_df['loan_status_low_risk']

# %%
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=10000000)

# %%
print(f"Training Data Score: {classifier.score(X_train, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test, y_test)}")
# Out:
# Training Data Score: 0.7008210180623974
# Testing Data Score: 0.5648660144619311

# %%
# Train a Random Forest Classifier model and print the model score
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(random_state=1, n_estimators=500).fit(X_train, y_train)
print(f'Training Score: {clf.score(X_train, y_train)}')
print(f'Testing Score: {clf.score(X_test, y_test)}')
# Out:
# Training Score: 1.0
# Testing Score: 0.6180348787749894

# %%
# Scale the data
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler().fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Train the Logistic Regression model on the scaled data and print the model score
classifier.fit(X_train_scaled, y_train)
print(f"Training Data Score: {classifier.score(X_train, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test, y_test)}")
# Out:
# Training Data Score: 0.5110016420361247
# Testing Data Score: 0.5491280306252658

# %%
# Train a Random Forest Classifier model on the scaled data and print the model score
clf = RandomForestClassifier(random_state=1, n_estimators=500).fit(X_train_scaled, y_train)
print(f'Training Score: {clf.score(X_train_scaled, y_train)}')
print(f'Testing Score: {clf.score(X_test_scaled, y_test)}')
# Out:
# Training Score: 1.0
# Testing Score: 0.6193109315185028

# %% [markdown]
# ### Conclusions
#
# Overall, I felt that my expectations were mostly confirmed, as the logistic regression failed to classify, even when scaled, very far above a coin toss. The randomForest was better as I had thought it would be, but I'm surprised it only was able to yeild a 62% hit rate. This forest model was clearly overfitting on the train set, and perhaps addressing this would increase testing accuracy.
